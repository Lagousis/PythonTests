# %%
import pandas as pd

# %%
schema = ['BusinessDate',
          'Temp1',
          'CustomerID',
          'CustomerSegment',
          'RetailID',
          'DeviceID',
          'ModelType',
          'GameTheme',
          'Temp2',
          'AmountPlayed',
          'AmountWon',
          'NumberOfSpinWon',
          'NumberOfSpinLost',
          'Temp3',
          'Vendor',
          'SessionStart',
          'SessionEnd',
          'Temp4',
          'Street',
          'StreetNumber',
          'Municipality',
          'Region',
          'State',
          'ZipCode',
          'Temp5',
          'SquareMeters',
          'IGT_VLTS',
          'INGG_VLTS',
          'SYNOT_VLTS',
          'WMS_VLTS',
          'Temp6',
          'Temp7',
          'MinBet',
          'MaxBet',
          'RowsCategory',
          'NumberOfRows',
          'CashInfo',
          'HasBalander',
          'HasDoubleOption',
          'BonusCategory',
          'HasExtraBonus',
          'HasSpecialFeature',
          'Temp8',
          'Temp9',
          'OPAPPeppers',
          'SpinType',
          'Temp10',
          'StdDev',
          'StdDevCateg',
          'HitRatePerc',
          'VendorVolat',
          'TargetAudience',
          'VendorPeppers',
          'TrainerPeppers',
          'Temp11',
          'Gender',
          'CustomerAddress',
          'CustomerCity',
          'CustomerRegion',
          'CustomerZipCode',
          'CustomerBirthday',
          'CustomerLang',
          'CommunicationFlag',
          'LoyaltyFlag']

# %%
df = pd.read_csv('d:\\temp\\customer_sessions.csv', delimiter=';', header=None, 
                 names=schema)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (1,23,25,59) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head().T
# Out:
#                                                                    0  \
# BusinessDate                                              2019-04-15
# Temp1                                                     1955737670
# CustomerID                                                 ΣΤ3527416
# CustomerSegment                                              Adopter
# RetailID                                                      122481
# DeviceID                                            122481-G01624
# ModelType                                       prodiGi Vu / Upright
# GameTheme                                             BrilliantWilds
# Temp2                                                           0.01
# AmountPlayed                                                 19715.4
# AmountWon                                                     5056.4
# NumberOfSpinWon                                                 4925
# NumberOfSpinLost                                               27039
# ...
